# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Dönüştürülen ilk klasörlerden birinin ve içindeki csv'lerin yolunu veriyoruz
# (Klasör isimlerini kendi bilgisayarındaki bir örneğe göre güncelleyebilirsin)
sample_flight_dir = r"C:\Users\feyza\UAV_Anomaly_Project\data\raw\uav_sead\ulg_files\2018-10-01"

imu_path = os.path.join(sample_flight_dir, "08_53_13_sensor_combined_0.csv") 
air_path = os.path.join(sample_flight_dir, "08_53_13_vehicle_air_data_0.csv") 

try:
    df_imu = pd.read_csv(imu_path)
    df_air = pd.read_csv(air_path)
    
    print("--- IMU Veri Yapısı ---")
    print(df_imu[['timestamp', 'gyro_rad[0]', 'accelerometer_m_s2[0]']].head())
    
    print("\n--- Air Veri Yapısı ---")
    print(df_air[['timestamp', 'baro_alt_meter', 'baro_alt_meter']].head())
    
except Exception as e:
    print("Dosya okunurken hata oluştu. Henüz bu dosya dönüştürülmemiş olabilir:", e)
# Out:
# --- IMU Veri Yapısı ---
#    timestamp  gyro_rad[0]  accelerometer_m_s2[0]
# 0   52948485    -0.004421              -0.020445
# 1   52952485     0.004342              -0.002852
# 2   52956488    -0.001724              -0.016539
# 3   52960531    -0.004430              -0.018185
# 4   52964485     0.001864               0.001526
#
# --- Air Veri Yapısı ---
# Dosya okunurken hata oluştu. Henüz bu dosya dönüştürülmemiş olabilir: "['alt', 'vel_m_s'] not in index"
